# %%
import numpy as np
import pandas as pd
import re
from bs4 import BeautifulSoup
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in e:\aditi\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow-intel==2.14.0 in e:\aditi\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.24.3)
# Requirement already satisfied: setuptools in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.58.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in e:\aditi\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in e:\aditi\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in e:\aditi\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in e:\aditi\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in e:\aditi\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in e:\aditi\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in e:\aditi\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in e:\aditi\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in e:\aditi\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in e:\aditi\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in e:\aditi\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3>=2.0.5 in e:\aditi\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.5)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in e:\aditi\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\aditi\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\aditi\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in e:\aditi\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in e:\aditi\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in e:\aditi\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in e:\aditi\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)

# %%
from attention import AttentionLayer

# %%
data=pd.read_csv("/Users/Omkar/Downloads/Reviews.csv",nrows=100000)

# %%
data.drop_duplicates(subset=['Text'],inplace=True)  
data.dropna(axis=0,inplace=True)

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",

                           "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",

                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",

                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",

                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",

                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",

                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",

                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",

                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",

                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",

                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",

                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",

                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",

                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",

                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",

                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",

                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",

                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",

                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",

                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",

                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",

                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",

                           "you're": "you are", "you've": "you have"}

# %%
data['Text'][:10]
# Out:
# 0    I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1             Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2    This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3    If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4                                                               Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
# 5    I got a wild hair for taffy and ordered this five pound bag. The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc. My only complaint is there wa...
# 6    This saltwater taffy had great flavors and was very soft and chewy.  Each candy was individually wrapped well.  None of the candies were stuck together, which did happen in the expensive version, ...
# 7                                                               This taffy is so good.  It is very soft and chewy.  The flavors are amazing.  I would definitely recommend you buying it.  Very satisfying!!
# 8                                                                        Right now I'm mostly just sprouting this so my cats can eat the grass. They love it. I rotate it around with Wheatgrass and Rye too
# 9                                                                  This is a very healthy dog food. Good for their digestion. Also good for small puppies. My dog eats her required amount at every feeding.
# Name: Text, dtype: object

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Omkar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english')) 
def text_cleaner(text):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    tokens = [w for w in newString.split() if not w in stop_words]
    long_words=[]
    for i in tokens:
        if len(i)>=3:                  #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t))

# %%
data['Summary'][:10]
# Out:
# 0                            Good Quality Dog Food
# 1                                Not as Advertised
# 2                            "Delight" says it all
# 3                                   Cough Medicine
# 4                                      Great taffy
# 5                                       Nice Taffy
# 6    Great!  Just as good as the expensive brands!
# 7                           Wonderful, tasty taffy
# 8                                       Yay Barley
# 9                                 Healthy Dog Food
# Name: Summary, dtype: object

# %%
def summary_cleaner(text):
    newString = re.sub('"','', text)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    newString = newString.lower()
    tokens=newString.split()
    newString=''
    for i in tokens:
        if len(i)>1:                                 
            newString=newString+i+' '  
    return newString

#Call the above function
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(summary_cleaner(t))

data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary
data['cleaned_summary'].replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
data.replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
import matplotlib.pyplot as plt

text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.show()

# %%
cnt=0
for i in data['cleaned_summary']:
    if(len(i.split())<=8):
        cnt=cnt+1
print(cnt/len(data['cleaned_summary']))
# Out:
# 0.9419028431727635

# %%
max_text_len=30
max_summary_len=8

# %%
cleaned_text =np.array(data['cleaned_text'])
cleaned_summary=np.array(data['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
df=pd.DataFrame({'text':short_text,'summary':short_summary})

# %%
df['summary'] = df['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['text']),np.array(df['summary']),test_size=0.1,random_state=0,shuffle=True)

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

# %%
thresh=4

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 66.2372690310374
# Total Coverage of rare words: 2.931712225866499

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

x_voc
# Out:
# 8388

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

# %%
thresh=6

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 77.91431056981295
# Total Coverage of rare words: 5.376127937103547

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1
y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# (42759, 42759)

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
from keras import backend as K 
K.clear_session()

latent_dim = 300
embedding_dim=100

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              838800    ['input_1[0][0]']
#
#  lstm (LSTM)                 [(None, 30, 300),            481200    ['embedding[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 30, 300),            721200    ['lstm[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  embedding_1 (Embedding)     (None, None, 100)            203200    ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 30, 300),            721200    ['lstm_1[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  lstm_3 (LSTM)               [(None, None, 300),          481200    ['embedding_1[0][0]',
#                               (None, 300),                           'lstm_2[0][1]',
#                               (None, 300)]                           'lstm_2[0][2]']
#
#  attention_layer (Attention  ((None, None, 300),          180300    ['lstm_2[0][0]',
#  Layer)                       (None, None, 30))                      'lstm_3[0][0]']
#
#  concat_layer (Concatenate)  (None, None, 600)            0         ['lstm_3[0][0]',
#                                                                      'attention_layer[0][0]']
#
#  time_distributed (TimeDist  (None, None, 2032)           1221232   ['concat_layer[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 4848332 (18.49 MB)
# Trainable params: 4848332 (18.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/50
# 326/326 [==============================] - 676s 2s/step - loss: 3.0211 - val_loss: 2.7517
# Epoch 2/50
# 326/326 [==============================] - 720s 2s/step - loss: 2.6920 - val_loss: 2.6239
# Epoch 3/50
# 326/326 [==============================] - 720s 2s/step - loss: 2.5993 - val_loss: 2.5371
# Epoch 4/50
# 326/326 [==============================] - 1106s 3s/step - loss: 2.5169 - val_loss: 2.4728
# Epoch 5/50
# 326/326 [==============================] - 733s 2s/step - loss: 2.4673 - val_loss: 2.4376
# Epoch 6/50
# 326/326 [==============================] - 876s 3s/step - loss: 2.4156 - val_loss: 2.3936
# Epoch 7/50
# 326/326 [==============================] - 740s 2s/step - loss: 2.3736 - val_loss: 2.3596
# Epoch 8/50
# 326/326 [==============================] - 741s 2s/step - loss: 2.3333 - val_loss: 2.3379
# Epoch 9/50
# 326/326 [==============================] - 751s 2s/step - loss: 2.2924 - val_loss: 2.2951
# Epoch 10/50
# 326/326 [==============================] - 745s 2s/step - loss: 2.2519 - val_loss: 2.2899
# Epoch 11/50
# 326/326 [==============================] - 742s 2s/step - loss: 2.2173 - val_loss: 2.2481
# Epoch 12/50
# 326/326 [==============================] - 2457s 8s/step - loss: 2.1882 - val_loss: 2.2443
# Epoch 13/50
# 326/326 [==============================] - 743s 2s/step - loss: 2.1626 - val_loss: 2.2057
# Epoch 14/50
# 326/326 [==============================] - 742s 2s/step - loss: 2.1388 - val_loss: 2.1990
# Epoch 15/50
# 326/326 [==============================] - 743s 2s/step - loss: 2.1178 - val_loss: 2.1817
# Epoch 16/50
# 326/326 [==============================] - 746s 2s/step - loss: 2.0977 - val_loss: 2.1765
# Epoch 17/50
# 326/326 [==============================] - 741s 2s/step - loss: 2.0786 - val_loss: 2.1680
# Epoch 18/50
# 326/326 [==============================] - 740s 2s/step - loss: 2.0603 - val_loss: 2.1656
# Epoch 19/50
# 326/326 [==============================] - 746s 2s/step - loss: 2.0413 - val_loss: 2.1477
# Epoch 20/50
# 326/326 [==============================] - 744s 2s/step - loss: 2.0219 - val_loss: 2.1491
# Epoch 21/50
# 326/326 [==============================] - 742s 2s/step - loss: 2.0020 - val_loss: 2.1392
# Epoch 22/50
# 326/326 [==============================] - 739s 2s/step - loss: 1.9831 - val_loss: 2.1220
# Epoch 23/50
# 326/326 [==============================] - 744s 2s/step - loss: 1.9633 - val_loss: 2.1367
# Epoch 24/50
# 326/326 [==============================] - 746s 2s/step - loss: 1.9435 - val_loss: 2.1003
# Epoch 25/50
# 326/326 [==============================] - 743s 2s/step - loss: 1.9240 - val_loss: 2.1053
# Epoch 26/50
# 326/326 [==============================] - 745s 2s/step - loss: 1.9049 - val_loss: 2.0894
# Epoch 27/50
# 326/326 [==============================] - 746s 2s/step - loss: 1.8874 - val_loss: 2.0947
# Epoch 28/50
# 326/326 [==============================] - 736s 2s/step - loss: 1.8682 - val_loss: 2.0938
# Epoch 28: early stopping

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: ingredients seem good quality although nothing recognizable like merrick great mixing kibble moisten dog needs mush soft wet canned food
# Original summary: good mush
# 1/1 [==============================] - 1s 940ms/step
# 1/1 [==============================] - 0s 444ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not as expected
#
#
# Review: glaze become staple house add last two minutes steak finish steaks oven minutes degrees add touch glaze last minutes baking glaze top delicious
# Original summary: great steak
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: happy quick delivery product fresh beans looking forward homemade vanilla extract done brewing would definitely buy seller
# Original summary: wonderfully fresh
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: item allows convenience safe place emergency hides well pantry know whenever need
# Original summary: safe safe
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: claiming coffee expert anything like nice cup espresso americano morning use bean love taste
# Original summary: love this bean
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great coffee
#
#
# Review: whole department addicted wonderful little treats candy jar empty end week much better option rather small bags getting local pharmacy store individually wrapped pieces make treat everyone grab
# Original summary: office addiction
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: salty taste readily available grocery store seems best bet hit market serving never know using small drinking glass used small screws nuts others
# Original summary: decent grocery store
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  delicious
#
#
# Review: surprised noodles like spicy food want something take winter edge get easy make
# Original summary: very good
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  not as good as the
#
#
# Review: marinade makes best fajitas ever looked eastern find product always supply hand
# Original summary: best marinade
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great product
#
#
# Review: treats great overly sensitive dog love upset stomach corn wheat products whats love small long way easy feed highly recommended
# Original summary: great natural treat
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  my dogs love these
#
#
# Review: great product great deal works great shakes weight loss buy product
# Original summary: great product
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great product
#
#
# Review: personally love goods amazon time par expectations always return without big hassle pack prunes however morning without stomach pain since advice stay away well unless loved without issues
# Original summary: this thing brings stomach and diarrhea
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great product
#
#
# Review: tried alot asparagus far best enjoyed garlic spices lightly pickled variety excellant bloody mary vendor job done right also highly recommend brussel sprouts even think like brussel sprouts stars winner
# Original summary: wow these are fantastic
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  best rice ever
#
#
# Review: food great bag got amazon seemed stale half smashed powder get better elsewhere
# Original summary: food but do not buy it here
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# Predicted summary:  not as advertised
#
#
# Review: searching hot sauces peppers compliment cuisine finally found like everything hot insanity sauce others less intense anyone wanting use sauces read instructions bottles good job dave
# Original summary: wow it is hot
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  hot sauce
#
#
# Review: love bigelow tea hard find decaf tea cups tasty tea
# Original summary: great
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  tea
#
#
# Review: tasted disgusting bland compared canned pumpkin usually purchase store brand savings worth sacrifice flavor typically eat pumpkin straight cheap convenient healthy
# Original summary: tasted disgusting
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  not what expected
#
#
# Review: crackers terrific priced right however ordered expiration date box eaten four boxes still taste fine expiration date really expected consume boxes months
# Original summary: too soon
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# Predicted summary:  not as expected
#
#
# Review: one favorite dishes always tough time finding local supermarkets like usually amazon sure enough available much lower price shipment boxes know gone time put automatic delivery searching supermarkets love
# Original summary: love these
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# Predicted summary:  great product
#
#
# Review: absolutely love tomatoes slices thought bits might good soups etc seem sweet flavor slices back slices whole great product
# Original summary: prefer the whole slices
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not as good as other
#
#
# Review: son celiac tried many bread products since diagnosis months ago hated except one bread good tried recipe bag bagels great pleased decent bagel pack lunch instead horrible smelling frozen ones
# Original summary: try the
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  yummy
#
#
# Review: expert seemed fine nothing extraordinary bought bag indian grocer seem awfully expensive
# Original summary: fine but premium pricing
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  not what expected
#
#
# Review: although packaged sent timely manner sent wrong item ordered hersheys milk chocolate sent hersheys almonds
# Original summary: sent the wrong item
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# Predicted summary:  great product
#
#
# Review: like switch foods dog hand mornings short time wonderful dog really likes serving fast mess
# Original summary: handy dog food
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# Predicted summary:  my dog loves these
#
#
# Review: picky eater like dog food treats loves chef michael discovered brand year ago much better ate brands grilled sirloin flavor new likes much chicken flavor would eating
# Original summary: loves it
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  my dog loves these
#
#
# Review: good value pound per pound compared folgers usually buy tastes smoother folgers none acid feeling slight get drinking much coffee milder blend good taste would
# Original summary: good value
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# Predicted summary:  great coffee
#
#
# Review: beans way bpa free cans sourced small farms usa eden oldest natural organic food company north america beans great recipe calls beans texture great taste
# Original summary: bpa free small farms
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: bought case work tasty coffee strong coffee thought medium body bolder type coffee tastes good taste
# Original summary: good strong coffee
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# Predicted summary:  great coffee
#
#
# Review: bought training cavalier king charles spaniel puppy goes nuts things peanut butter flavor anything get treats
# Original summary: crazy for zukes
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  my dogs love these
#
#
# Review: coffee arrived days fresh great price great cup coffee
# Original summary: cups
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# Predicted summary:  great coffee
#
#
# Review: cannot believe wonderful chip slightly spicy taste gives chip extra punch flavor family addicted
# Original summary: amazing taste best chip ever
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  yummy
#
#
# Review: use sweetener everything flavor light definitely sweet enough soothe sweetest tooth mixes quickly iced teas cold drinks love
# Original summary: sweet agave goodness
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  ginger tea
#
#
# Review: discovered years ago halloween packaged black called milk choco sooo smooth bite white inside like explosion richness going plan trip switzerland every single cent
# Original summary: died and gone to heaven
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: cheese lover ship come gonna love product especially add ground beef turkey daughter says taste like hamburgers eats know going winner dinner table
# Original summary: yummy
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great product
#
#
# Review: really like exercise although probably buy flavored next time play lots senior softball hot weather converted guys team drink electrolytes give try
# Original summary: zico coconut water
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  good stuff
#
#
# Review: regret buying gift basket picture shows price bought chocolate set rather
# Original summary: gift basket sucks
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# Predicted summary:  great product
#
#
# Review: jerky really delicious vegetarian always getting picked eating rabbit food everyone got taste could believe meat loved
# Original summary: great product
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great product
#
#
# Review: great product mother loved would definitely reorder enjoy popcorn much thanks
# Original summary: fast and pleased
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: ordered worker absolutely loves brownies said soon takes oven eats chance freezer like recommended
# Original summary: wonderful
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  yummy
#
#
# Review: enjoy ever step gained lbs within month buying pack full sized bags damn warn tastes awesome though finish crash diet order another box
# Original summary: these chips will make you fat
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: ordered flavor cup amazon sounded darn good flavors mix mouth drink use cream coffee dilute delightful flavor try pleased
# Original summary: delightful
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  best decaf coffee
#
#
# Review: normally share folks around however boy good hard couple bags like glenny items however one really good
# Original summary: it hard to with these things
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  not bad
#
#
# Review: cannot get libby happy get restrict organic watery however requires either recipe review organic pumpkin
# Original summary: organic canned
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not as advertised
#
#
# Review: dog ate product packaged thailand got immediately sick threw worried something nasty
# Original summary: my dog ate it and got sick
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  my dogs love it
#
#
# Review: product recommended low glycemic index sweetner tried stevia care aftertaste found agava nectar really work well cannot tell difference cereal iced tea amazon price much cheaper grocery store shop
# Original summary: great substitute for sugar
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good stuff
#
#
# Review: best gluten free bread cook longer says package done middle cook total minutes first cover get brown min let cook another mins yummy
# Original summary: awsome gluten free bread
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  best gluten free pasta
#
#
# Review: thank much offering one favorite products cheap package great service buy
# Original summary: great
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: daughter moved new home washington state san diego california grandkids loved housewarming gift
# Original summary: bought for
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great gift
#
#
# Review: got back christmas party absolutely best gummis ever tasted host told purchased could believe juicy good flavor much sugar taste enjoy gummi candy try
# Original summary: juicy
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: love product use frozen lower cal desert also made chocolate cal cocoa yummy
# Original summary: just like peanut butter
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  delicious
#
#
# Review: admit terribly fond flavored coffees one love rodeo drive good loves coffee sent
# Original summary: crazy flavor combination
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great coffee
#
#
# Review: love maple sugar grocery store longer sells get
# Original summary: this item and it got here quickly
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: think good toy hard border collie get food treats food smaller drop easily
# Original summary: good but not for
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  my dog loves these
#
#
# Review: circumstances beyond control product become quite good purchase easy care well worth money
# Original summary: lucky
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  not what expected
#
#
# Review: month old refused eat bite stuff tried could blame stuff tastes terrible
# Original summary: yuck
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  not bad
#
#
# Review: choo choo snacks unusual customer service customer feedback attention customer makes company worth business
# Original summary: great company great customer service
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: great hydrating product natural find cheaper vitacost free fyi
# Original summary: great natural coconut water taste great
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great product
#
#
# Review: particular coffee bit strong taste worth try certainly get good amount coffee money
# Original summary: price is right
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  good coffee
#
#
# Review: like sticky rice could find local stores rice nothing like sticky rice restaurants small rice sticky clumps together blobs literally difficult wash big disappointment buy
# Original summary: sweet rice
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  best rice rice ever
#
#
# Review: love baking soda used sorts things around house arm hammer one best baking soda brands
# Original summary: so many uses
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great gift
#
#
# Review: product salted foul artificial flavor worth anything waste money
# Original summary: terrible
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not what expected
#
#
# Review: wonderful cocoa powder chocolate needs even special organic free pesticides harmful chemicals
# Original summary: now cocoa
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great taste
#
#
# Review: walkers treacle best treacle desirable chewing consistency taste package well priced delivery prompt wish larger per pack amount available
# Original summary: lovers dream
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great product
#
#
# Review: tried many different brands many different price points love dunkin donuts hate starbucks favorite coffee brand love mocha flavor
# Original summary: love this coffee
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great coffee
#
#
# Review: sceptical first tried first bag hooked easy prepare microwave minute half come perfect nice salty fresher ones get bags store hardest part waiting cool
# Original summary: love these
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great product
#
#
# Review: buy exact kit target save outrageous price ridiculous shipping costs normally like deals highway robbery amazon
# Original summary: not deal
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  not as advertised
#
#
# Review: cups tried best never bitter always strong enough good bold flavor come thru tried others listed bold lacked depth bitterness newman special blend way
# Original summary: the best
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  best coffee
#
#
# Review: appreciate good cup tea enjoy one brew according instructions make sure end lovely cup finest tea
# Original summary: excellent earl grey
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# Predicted summary:  tea
#
#
# Review: showed day expired returns food items fyi think feeding month old child expired food good idea
# Original summary: read this
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  good product
#
#
# Review: old biscotti bit bigger new one liked old size better
# Original summary: size
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not what expected
#
#
# Review: dental chews right size golden retrievers love chews arrived promptly good condition
# Original summary: good deal
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  my dog loves these
#
#
# Review: everyone loved haribo gummi candy original gold bears ounce bags
# Original summary: haribo gummi bears
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  gummi bears
#
#
# Review: really resemble tartness regular old clover honey much prefer company offering ounce bottle
# Original summary: good honey but think it is just
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great product
#
#
# Review: never loved dry food one knew would love one could eat literally almost every day cannot wait try flavors
# Original summary: he loves it
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great for my baby
#
#
# Review: item mail hungry girl thought would give try aside sesame seeds teeth product wonderful taste different anything ever tasted great combination flavor would definitely recommend
# Original summary: soooo good
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good stuff
#
#
# Review: ordered one package wished ordered four delicious liked simple instructions preparing
# Original summary: like these
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great product
#
#
# Review: really good product unhealthy important microwaved different taste easy
# Original summary: yummy
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  good stuff
#
#
# Review: using blue cat food years happy cat years old seems healthy content received food within days great service
# Original summary: great and healthy for cats
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  my cats love this
#
#
# Review: award winning secret ingredient barbecued ribs chicken wings burgers mixed little habenero pepper plant sauce unbelievably good wings barbecued products oven reason
# Original summary: awesome product chicken product
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great product
#
#
# Review: found coffee bitter flavor required creamer like smooth taste packaging real plus though try san francisco bay coffees see find one like
# Original summary: nice packaging but bitter flavor
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great coffee
#
#
# Review: indeed rich creamy chocolaty delight use smallest cup size machine remember shake box well using cocoa still remains cup brewing regardless get satisfying cup hot cocoa
# Original summary: an instant favorite
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  delicious
#
#
# Review: produced york long time ago mexico great taste knows years way one boxes taste good enough never know like originals york something like need imported
# Original summary: they re mints now
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not what expected
#
#
# Review: melitta rich flavourful product delicious treat comparable coffees much higher price tag plus decaffeinated version sacrifice flavour highly recommended
# Original summary: excellent quality and value
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  delicious
#
#
# Review: green mountain favorite brand nantucket favorite coffee green mountain smooth flavor strong weak
# Original summary: my favorite
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great coffee
#
#
# Review: noodles good hot enough good taste much like chilly
# Original summary: noodles
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  amazing
#
#
# Review: two old twins way eat oatmeal combination pear convenient especially quickly mixing breakfast morning packaging amazon always secure never broken jars recommended
# Original summary: babies love this
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  my baby loves these
#
#
# Review: hype stuff hardly anything best one amp guess every one different works one may work another best experiment different drinks find one job
# Original summary: just okay ve had better
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great product
#
#
# Review: really good buy alfalfa seeds run couple ounces whole pound less small amount bad seeds easy skim seems germinate close
# Original summary: great buy on lots of seeds
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great gift
#
#
# Review: quality stores area carry slightly less expensive mushy taste adequate pizzas one dented leaked amazon immediately gave choice partial credit return cans could ask
# Original summary: good enough
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  not as advertised
#
#
# Review: beware photo plant order page shows large white flowers flowers two plants shipped amazon unsatisfactory particularly expensive plant
# Original summary: no flowers
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  not as advertised
#
#
# Review: one best white cheese brand north west turkey delicious feta
# Original summary: white cheese from
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: husband gluten free years believe tried product closest regular pasta ever tried know texture bigger problem comes gluten free food product measures niece came visit says favorite
# Original summary: cannot believe it is not gluten
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great gluten free pasta
#
#
# Review: one weaker flavored coffees yummy one almost need milk already creamy tasting
# Original summary: yum but weak
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great coffee
#
#
# Review: little rescue mini poodle loves wonderful little chews small dogs like benefit cleaning done
# Original summary: loves them
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  my dog loves these
#
#
# Review: seen shelf decided buy although boxes lot great butter honey tried anything else thin fragile whatever put stand still healthy taste
# Original summary: very nice
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: chocolate wonderful prefer sipping chocolate people keen dark rich chocolate mix great
# Original summary: mmmmmmm
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  chocolate
#
#
# Review: looking something easy prepare meatless healthy madras entree suggested heat eat never got far love cold madras entrees one wonderful must try amazon shipping great
# Original summary: healthy very tasty
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: stash tea one best available green tea one finest products price amazon cannot wrong saved dollars buying
# Original summary: the stash baby
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  tea
#
#
# Review: picture cup shows extra bold received light roast disappointed maybe price lower others careful ordering
# Original summary: not extra bold
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  not bad
#
#
# Review: cannot say enough king flour flour use home thrilled see offered amazon please keep offering
# Original summary: absolutely best flour on market
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product
